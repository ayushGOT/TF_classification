# %%
import localcider
from localcider.sequenceParameters import SequenceParameters
import pandas as pd

# %%
def kappa(sequence):
    
# create a SequenceParameters object with your amino acid sequence
    SeqOb = SequenceParameters(sequence)

    # carry out analysis
    return(SeqOb.get_kappa())

# %%
tf1 = pd.read_csv('Full-DBDs.csv').dropna()
tf1.reset_index(inplace=True)

# %%
print (tf1['Sequence'][345].apply(kappa))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 print (tf1['Sequence'][345].apply(kappa))
#
# AttributeError: 'str' object has no attribute 'apply'
